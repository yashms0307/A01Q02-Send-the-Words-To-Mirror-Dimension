# %% [markdown]
# # Send the Words To Mirror Dimension

# %% [markdown]
# Assignment 1 : Operators | Loops
#
# Question 2
#
# Write a Python program that accepts a word from the user and reverse it.

# %%
User_Input_Word = input("Enter the word you want to reverse : ")
Reversed_Word = User_Input_Word[::-1]
print("Reversed Word Is : ", Reversed_Word)
# Out:
# Enter the word you want to reverse : Edyoda
# Reversed Word Is :  adoydE
